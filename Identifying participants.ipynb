# %% [markdown]
# # What this file does

# %% [markdown]
# I started off trying to identify participants in this analysis, and came across Tom Pavlik and Richard Bednarz in the data. I also realized that there's some overlap between by FEMA data and the New Jersey Blue Acres buyout data — I had asked for non-FEMA buyout data, but they just shared what looks to be their whole database with me. I mapped out the two datasets to see if there was a one-to-one overlap, and realized that there was not and that I would need to consider both datasets. (Some communities can — and have, especially in the case of Wayne — applied to FEMA directly for money. Keep in mind that Wayne conducted buyouts well before Blue Acres.) I then try to establish how many unique buyouts I am dealing with in the two datasets.

# %% [markdown]
# # Trying to find people

# %%
import pandas as pd

# %%
# !ls
# Out:
# Identifying participants.ipynb buyouts_geo_NJ_state.csv
# Total buyouts per county.ipynb map.pdf
# buyouts_geo_NJ_FEMA.csv

# %%
df = pd.read_csv('buyouts_geo_NJ_FEMA.csv')

# %%
len(df)
# Out:
# 1848

# %%
df.dtypes
# Out:
# ID                      float64
# Fiscal Year               int64
# Disaster Description     object
# Residence                object
# Owner                    object
# Structure                object
# Address                  object
# City                     object
# State                    object
# Zip                       int64
# Price Paid               object
# Status                   object
# Country                  object
# Address_Full             object
# lat                     float64
# lng                     float64
# dtype: object

# %%
df['Owner'].value_counts(dropna=False, normalize=True)
# Out:
# HOUSING CORP, OCEAN SENIOR CITIZENS    0.007576
# NaN                                    0.006494
# GROTENHUIS, STEPHEN                    0.002165
# SULEJMANI, KUJTIM                      0.002165
# BAJRAMI, BELUL                         0.001623
#                                          ...
# BYCHKOWSKI, OLGA                       0.000541
# HARRIS, JULIA                          0.000541
# ANDERS III, WILLIAM M                  0.000541
# INGRAM, ROBERT                         0.000541
# MANEEN, RICHARD & MARIA                0.000541
# Name: Owner, Length: 1694, dtype: float64

# %%
df[df['City'].str.contains('SAYREVILLE')==True]
# Out:
#            ID  Fiscal Year Disaster Description  \
# 860   41551.0         2013      HURRICANE SANDY
# 861   41552.0         2013      HURRICANE SANDY
# 863   41570.0         2013      HURRICANE SANDY
# 865   41572.0         2013      HURRICANE SANDY
# 866   41573.0         2013      HURRICANE SANDY
# ...       ...          ...                  ...
# 1677  42384.0         2013      HURRICANE SANDY
# 1678  42385.0         2013      HURRICANE SANDY
# 1681  42388.0         2013      HURRICANE SANDY
# 1682  42389.0         2013      HURRICANE SANDY
# 1683  42390.0         2013      HURRICANE SANDY
#
#                                  Residence             Owner      Structure  \
# 860   Owner Occupied - Principal Residence      OZGA, ANDREJ  Single Family
# 861   Owner Occupied - Principal Residence  BENTIVENGA, LOIS  Single Family
# 863   Owner Occupied - Principal Residence   HOGUE, KATHLEEN  Single Family
# 865   Owner Occupied - Principal Residence  MARKULIC, EVELYN  Single Family
# 866   Owner Occupied - Principal Residence        DAMANIA, A  Single Family
# ...                                    ...               ...            ...
# 1677  Owner Occupied - Principal Residence       LOZA, CINDY  Single Family
# 1678  Owner Occupied - Principal Residence   KNOPOKA, ELAINE  Single Family
# 1681  Owner Occupied - Principal Residence     MALET, RONALD  Single Family
# 1682  Owner Occupied - Principal Residence    MARIANO, ARTUR     2-4 Family
# 1683  Owner Occupied - Principal Residence     CASEY, THOMAS  Single Family
#
#                  Address        City State   Zip Price Paid    Status Country  \
# 860    63 MAC ARTHUR AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# 861    66 MAC ARTHUR AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# 863        100 WEBER AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# 865   101 MAC ARTHUR AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# 866        101 WEBER AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# ...                  ...         ...   ...   ...        ...       ...     ...
# 1677   97 MAC ARTHUR AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# 1678        97 WEBER AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# 1681   98 MAC ARTHUR AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# 1682        98 WEBER AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# 1683   99 MAC ARTHUR AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
#
#                             Address_Full        lat        lng
# 860    63 MAC ARTHUR AVE, SAYREVILLE, NJ  40.458942 -74.368301
# 861    66 MAC ARTHUR AVE, SAYREVILLE, NJ  40.459015 -74.367705
# 863        100 WEBER AVE, SAYREVILLE, NJ  40.463038 -74.369698
# 865   101 MAC ARTHUR AVE, SAYREVILLE, NJ  40.460831 -74.368484
# 866        101 WEBER AVE, SAYREVILLE, NJ  40.462835 -74.369217
# ...                                  ...        ...        ...
# 1677   97 MAC ARTHUR AVE, SAYREVILLE, NJ  40.460553 -74.368438
# 1678        97 WEBER AVE, SAYREVILLE, NJ  40.462641 -74.369217
# 1681   98 MAC ARTHUR AVE, SAYREVILLE, NJ  40.460788 -74.367888
# 1682        98 WEBER AVE, SAYREVILLE, NJ  40.462821 -74.369675
# 1683   99 MAC ARTHUR AVE, SAYREVILLE, NJ  40.460709 -74.368438
#
# [137 rows x 16 columns]

# %%
df[df['City'].str.contains('WAYNE')==True]
# Out:
#            ID  Fiscal Year        Disaster Description  \
# 112   27900.0         2004  SEVERE STORMS AND FLOODING
# 113   27901.0         2004  SEVERE STORMS AND FLOODING
# 116   27904.0         2004  SEVERE STORMS AND FLOODING
# 117   27905.0         2004  SEVERE STORMS AND FLOODING
# 123   30600.0         2006                         NaN
# ...       ...          ...                         ...
# 1843  43675.0         2016                         NaN
# 1844  43676.0         2016                         NaN
# 1845  43677.0         2016                         NaN
# 1846  43678.0         2016                         NaN
# 1847  43679.0         2016                         NaN
#
#                                  Residence                             Owner  \
# 112   Owner Occupied - Principal Residence                  LA MONICA, HEIDI
# 113   Owner Occupied - Principal Residence                      DAWSON, MARK
# 116   Owner Occupied - Principal Residence                    GROVE, VIRGINA
# 117                                    NaN                         OSSI, RON
# 123                                  Other  CONDO ASSOCIATION, HOFFMAN GROVE
# ...                                    ...                               ...
# 1843                                   NaN                     HANDL, GYORGY
# 1844                                   NaN                   LOMBARDO, JAMES
# 1845                                   NaN                   KANG, MOON BACK
# 1846                                   NaN                 DUBNICZKI, GEORGE
# 1847                                   NaN                  SULLIVAN, ROBERT
#
#           Structure          Address   City State   Zip Price Paid     Status  \
# 112   Single Family     14 MAIN ROAD  WAYNE    NJ  7470        NaN     Closed
# 113   Single Family     15 MAIN ROAD  WAYNE    NJ  7470        NaN     Closed
# 116   Single Family      3 WEST ROAD  WAYNE    NJ  7470        NaN     Closed
# 117   Single Family    4 SPRING ROAD  WAYNE    NJ  7470        NaN     Closed
# 123   Single Family      11 NORTH RD  WAYNE    NJ  7470        NaN     Closed
# ...             ...              ...    ...   ...   ...        ...        ...
# 1843  Single Family      35 SHORE RD  WAYNE    NJ  7470        NaN  Obligated
# 1844  Single Family  38 NEW YORK AVE  WAYNE    NJ  7470        NaN  Obligated
# 1845  Single Family         60 MAPLE  WAYNE    NJ  7470        NaN  Obligated
# 1846  Single Family  64 FAIRFIELD RD  WAYNE    NJ  7470        NaN  Obligated
# 1847  Single Family    64 HOBSON AVE  WAYNE    NJ  7470        NaN  Obligated
#
#      Country                Address_Full        lat        lng
# 112      USA     14 MAIN ROAD, WAYNE, NJ  40.917241 -74.274575
# 113      USA     15 MAIN ROAD, WAYNE, NJ  40.917100 -74.274789
# 116      USA      3 WEST ROAD, WAYNE, NJ  40.916542 -74.277483
# 117      USA    4 SPRING ROAD, WAYNE, NJ  40.916964 -74.274085
# 123      USA      11 NORTH RD, WAYNE, NJ  40.979721 -74.274895
# ...      ...                         ...        ...        ...
# 1843     USA      35 SHORE RD, WAYNE, NJ  40.977013 -74.280538
# 1844     USA  38 NEW YORK AVE, WAYNE, NJ  40.925338 -74.266648
# 1845     USA         60 MAPLE, WAYNE, NJ  40.973738 -74.276917
# 1846     USA  64 FAIRFIELD RD, WAYNE, NJ  40.894910 -74.266144
# 1847     USA    64 HOBSON AVE, WAYNE, NJ  40.890189 -74.245283
#
# [485 rows x 16 columns]

# %%
df[df['City'].str.contains('WAYNE')==True][df['Owner'].str.contains('WATSON')==True]
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [ID, Fiscal Year, Disaster Description, Residence, Owner, Structure, Address, City, State, Zip, Price Paid, Status, Country, Address_Full, lat, lng]
# Index: []

# %%
#When did buyouts peak in these communities? Both after Sandy/ Interestingly Sayreville looks like a one-time buyout deal

# %%
df[df['City'].str.contains('WAYNE')==True].groupby('Fiscal Year')['City'].value_counts()
# Out:
# Fiscal Year  City
# 2004         WAYNE      4
# 2006         WAYNE     40
# 2007         WAYNE     36
# 2009         WAYNE     28
# 2010         WAYNE     83
# 2011         WAYNE     56
# 2013         WAYNE    170
# 2015         WAYNE     54
# 2016         WAYNE     14
# Name: City, dtype: int64

# %%
df[df['City'].str.contains('SAYREVILLE')==True].groupby('Fiscal Year')['City'].value_counts()
# Out:
# Fiscal Year  City
# 2013         SAYREVILLE    137
# Name: City, dtype: int64

# %%
#no buyouts in little egg as per this

# %%
df[df['City'].str.contains('Egg')==True]
# Out:
# Empty DataFrame
# Columns: [ID, Fiscal Year, Disaster Description, Residence, Owner, Structure, Address, City, State, Zip, Price Paid, Status, Country, Address_Full, lat, lng]
# Index: []

# %% [markdown]
# # Comparing the two datasets

# %%
df_2 = pd.read_csv('buyouts_geo_NJ_state.csv')

# %%
len(df_2)
# Out:
# 494

# %%
df_Sayreville_NJ_state = df_2[df_2['Town']=='Sayreville']

# %%
df_Sayreville_NJ_state['Year'] = df_Sayreville_NJ_state['Date Closed'].str.extract(r'(\d\d\d\d)')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_Sayreville_NJ_state['Year'].value_counts()
# Out:
# 2014    105
# 2013     21
# 2015     15
# 2016      6
# 2017      1
# Name: Year, dtype: int64

# %%
df_Sayreville_NJ_state[(df_Sayreville_NJ_state['Year']=='2013')&(df_Sayreville_NJ_state['Address_Full'].str.contains("Weber"))]
# Out:
#    Date Closed Disaster Description  \
# 8   10/15/2013      Hurricane Sandy
# 22  11/18/2013      Hurricane Sandy
# 23  11/19/2013      Hurricane Sandy
# 25  12/11/2013      Hurricane Sandy
# 26  12/11/2013      Hurricane Sandy
# 27  12/12/2013      Hurricane Sandy
# 28  12/13/2013      Hurricane Sandy
# 39  12/19/2013      Hurricane Sandy
# 43  12/26/2013      Hurricane Sandy
# 53  12/30/2013      Hurricane Sandy
# 54  12/30/2013      Hurricane Sandy
# 55  12/31/2013      Hurricane Sandy
#
#                                     Type of Structure        Address  \
# 8                                            2 Sheds   127 Weber Ave
# 22                                                     128 Weber Ave
# 23   Front & side of foundation, back foundation m...   20 Weber Ave
# 25   8 Room split level home with basement and 1-c...   88 Weber Ave
# 26                                           2 sheds    15 Weber Ave
# 27                                        Ranch Home    19 Weber Ave
# 28   Home-2 story Colonial-No damage now-has been ...   12 Weber Ave
# 39    Photos enclosed.  House, shed & fence damaged.    85 Weber Ave
# 43                                                      50 Weber Ave
# 53   It is a split leverl house with basement & at...   97 Weber Ave
# 54                                 House, pool, shed    25 Weber Ave
# 55                                                      38 Weber Ave
#
#           Town                   Address_Full        lat        lng  \
# 8   Sayreville  127 Weber Ave, Sayreville, NJ  40.465121 -74.366926
# 22  Sayreville  128 Weber Ave, Sayreville, NJ  40.465404 -74.367293
# 23  Sayreville   20 Weber Ave, Sayreville, NJ  40.456758 -74.369079
# 25  Sayreville   88 Weber Ave, Sayreville, NJ  40.462226 -74.369583
# 26  Sayreville   15 Weber Ave, Sayreville, NJ  40.456734 -74.368621
# 27  Sayreville   19 Weber Ave, Sayreville, NJ  40.457051 -74.368667
# 28  Sayreville   12 Weber Ave, Sayreville, NJ  40.456480 -74.369034
# 39  Sayreville   85 Weber Ave, Sayreville, NJ  40.462030 -74.369148
# 43  Sayreville   50 Weber Ave, Sayreville, NJ  40.459321 -74.369354
# 53  Sayreville   97 Weber Ave, Sayreville, NJ  40.462641 -74.369217
# 54  Sayreville   25 Weber Ave, Sayreville, NJ  40.457229 -74.368690
# 55  Sayreville   38 Weber Ave, Sayreville, NJ  40.458456 -74.369332
#
#    Year of Closing  Year
# 8             2013  2013
# 22            2013  2013
# 23            2013  2013
# 25            2013  2013
# 26            2013  2013
# 27            2013  2013
# 28            2013  2013
# 39            2013  2013
# 43            2013  2013
# 53            2013  2013
# 54            2013  2013
# 55            2013  2013

# %%
df_2.describe
# Out:
# <bound method NDFrame.describe of     Date Closed Disaster Description  \
# 0     8/25/2014      Hurricane Sandy
# 1     9/12/2014      Hurricane Sandy
# 2     8/29/2014      Hurricane Sandy
# 3     8/28/2014      Hurricane Sandy
# 4      9/5/2014      Hurricane Sandy
# ..          ...                  ...
# 489    8/7/2019      Hurricane Sandy
# 490   9/20/2018      Hurricane Sandy
# 491   12/4/2017      Hurricane Sandy
# 492  10/25/2018      Hurricane Sandy
# 493    2/5/2018      Hurricane Sandy
#
#                                      Type of Structure               Address  \
# 0                                        2 car garage        77 Crampton Ave
# 1                                                         563 Heidelberg Ave
# 2                                                             535 Vesper Ave
# 3                                                             558 Vesper Ave
# 4                                   Shed, not damaged         526 Watson Ave
# ..                                                 ...                   ...
# 489   House-primary residence.  No damage-see attac...         10 Lee Street
# 490                                              Shed        7 Martin Avenue
# 491                                    Garage (2 car)       13 Martin Avenue
# 492                             Just the house itself   129 Whitehead Avenue
# 493                                                        40 Belmont Avenue
#
#             Town                           Address_Full        lat        lng
# 0     Woodbridge        77 Crampton Ave, Woodbridge, NJ  40.559312 -74.270579
# 1     Woodbridge     563 Heidelberg Ave, Woodbridge, NJ  40.559487 -74.269398
# 2     Woodbridge         535 Vesper Ave, Woodbridge, NJ  40.558189 -74.268986
# 3     Woodbridge         558 Vesper Ave, Woodbridge, NJ  40.559178 -74.268081
# 4     Woodbridge         526 Watson Ave, Woodbridge, NJ  40.558226 -74.270361
# ..           ...                                    ...        ...        ...
# 489  South River         10 Lee Street, South River, NJ  40.449842 -74.373844
# 490  South River       7 Martin Avenue, South River, NJ  40.449750 -74.376269
# 491  South River      13 Martin Avenue, South River, NJ  40.449918 -74.376364
# 492  South River  129 Whitehead Avenue, South River, NJ  40.447438 -74.374085
# 493  South River     40 Belmont Avenue, South River, NJ  40.455382 -74.384428
#
# [494 rows x 8 columns]>

# %%
df['Fiscal Year'].value_counts().sort_index()
# Out:
# 1996       3
# 1997       5
# 1998       9
# 1999      87
# 2000       7
# 2004       7
# 2005       5
# 2006      40
# 2007      37
# 2009      28
# 2010     117
# 2011     319
# 2012      26
# 2013    1007
# 2015     133
# 2016      18
# Name: Fiscal Year, dtype: int64

# %%
df[(df['Fiscal Year']==2013) & (df['City']=='SAYREVILLE') & (df['Address'].str.contains('WEBER'))]
# Out:
#            ID  Fiscal Year Disaster Description  \
# 863   41570.0         2013      HURRICANE SANDY
# 866   41573.0         2013      HURRICANE SANDY
# 871   41578.0         2013      HURRICANE SANDY
# 873   41580.0         2013      HURRICANE SANDY
# 875   41582.0         2013      HURRICANE SANDY
# ...       ...          ...                  ...
# 1667  42374.0         2013      HURRICANE SANDY
# 1669  42376.0         2013      HURRICANE SANDY
# 1676  42383.0         2013      HURRICANE SANDY
# 1678  42385.0         2013      HURRICANE SANDY
# 1682  42389.0         2013      HURRICANE SANDY
#
#                                  Residence               Owner      Structure  \
# 863   Owner Occupied - Principal Residence     HOGUE, KATHLEEN  Single Family
# 866   Owner Occupied - Principal Residence          DAMANIA, A  Single Family
# 871   Owner Occupied - Principal Residence     MELIAN, RICHARD  Single Family
# 873   Owner Occupied - Principal Residence  POPKOWSKI, TERRY E  Single Family
# 875   Owner Occupied - Principal Residence    ADRAGNA, BRIGIDA  Single Family
# ...                                    ...                 ...            ...
# 1667  Owner Occupied - Principal Residence      WILCHER, BRUCE  Single Family
# 1669  Owner Occupied - Principal Residence      PAVLIK, THOMAS  Single Family
# 1676  Owner Occupied - Principal Residence        JAVAID, AMER  Single Family
# 1678  Owner Occupied - Principal Residence     KNOPOKA, ELAINE  Single Family
# 1682  Owner Occupied - Principal Residence      MARIANO, ARTUR     2-4 Family
#
#             Address        City State   Zip Price Paid    Status Country  \
# 863   100 WEBER AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# 866   101 WEBER AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# 871   102 WEBER AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# 873   103 WEBER AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# 875   104 WEBER AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# ...             ...         ...   ...   ...        ...       ...     ...
# 1667   92 WEBER AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# 1669   93 WEBER AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# 1676   96 WEBER AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# 1678   97 WEBER AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
# 1682   98 WEBER AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
#
#                        Address_Full        lat        lng
# 863   100 WEBER AVE, SAYREVILLE, NJ  40.463038 -74.369698
# 866   101 WEBER AVE, SAYREVILLE, NJ  40.462835 -74.369217
# 871   102 WEBER AVE, SAYREVILLE, NJ  40.463236 -74.369583
# 873   103 WEBER AVE, SAYREVILLE, NJ  40.463062 -74.369171
# 875   104 WEBER AVE, SAYREVILLE, NJ  40.463534 -74.369217
# ...                             ...        ...        ...
# 1667   92 WEBER AVE, SAYREVILLE, NJ  40.462404 -74.369606
# 1669   93 WEBER AVE, SAYREVILLE, NJ  40.462441 -74.369171
# 1676   96 WEBER AVE, SAYREVILLE, NJ  40.462621 -74.369629
# 1678   97 WEBER AVE, SAYREVILLE, NJ  40.462641 -74.369217
# 1682   98 WEBER AVE, SAYREVILLE, NJ  40.462821 -74.369675
#
# [71 rows x 16 columns]

# %%
df[(df['Fiscal Year']>2013) & (df['City']=='SAYREVILLE')]
# Out:
# Empty DataFrame
# Columns: [ID, Fiscal Year, Disaster Description, Residence, Owner, Structure, Address, City, State, Zip, Price Paid, Status, Country, Address_Full, lat, lng]
# Index: []

# %%
df[(df['Fiscal Year']==2013) & (df['City']=='SAYREVILLE')&(df['Address'].str.contains('85 WEBER'))]
# Out:
#            ID  Fiscal Year Disaster Description  \
# 1637  42344.0         2013      HURRICANE SANDY
#
#                                  Residence               Owner      Structure  \
# 1637  Owner Occupied - Principal Residence  BEDNARZ, RICHARD A  Single Family
#
#            Address        City State   Zip Price Paid    Status Country  \
# 1637  85 WEBER AVE  SAYREVILLE    NJ  8872        NaN  Approved     USA
#
#                       Address_Full       lat        lng
# 1637  85 WEBER AVE, SAYREVILLE, NJ  40.46203 -74.369148

# %% [markdown]
# # How many unique buyouts

# %%
#using lat, lng for this because I'm seeing differences in case, spelling of the same street between datasets and I'm not going to hardocde fixes to that (seems risky)

# %%
new_df = pd.merge(df, df_2, left_on=['lat','lng'], right_on = ['lat','lng'])

# %%
new_df[['Address_Full_x', 'Address_Full_y']]
# Out:
#                            Address_Full_x  \
# 0       63 MAC ARTHUR AVE, SAYREVILLE, NJ
# 1       66 MAC ARTHUR AVE, SAYREVILLE, NJ
# 2           100 CAUSEWAY, SOUTH RIVER, NJ
# 3           100 WEBER AVE, SAYREVILLE, NJ
# 4      101 MAC ARTHUR AVE, SAYREVILLE, NJ
# ..                                    ...
# 429     98 MAC ARTHUR AVE, SAYREVILLE, NJ
# 430          98 WEBER AVE, SAYREVILLE, NJ
# 431         9 LEE STREET, SOUTH RIVER, NJ
# 432  9 LITTLE MARTIN AVE, SOUTH RIVER, NJ
# 433         9 MARTIN AVE, SOUTH RIVER, NJ
#
#                            Address_Full_y
# 0       63 Mac Arthur Ave, Sayreville, NJ
# 1        66 MacArthur Ave, Sayreville, NJ
# 2           100 Causeway, South River, NJ
# 3           100 Weber Ave, Sayreville, NJ
# 4      101 Mac Arthur Ave, Sayreville, NJ
# ..                                    ...
# 429     98 Mac Arthur Ave, Sayreville, NJ
# 430          98 Weber Ave, Sayreville, NJ
# 431         9 Lee Street, South River, NJ
# 432  9 Little Martin Ave, South River, NJ
# 433         9 Martin Ave, South River, NJ
#
# [434 rows x 2 columns]

# %%
#A union B = A + B - A intersect B

# %%
len(df)+len(df_2)-len(new_df)
# Out:
# 1908

# %%
#total number of buyouts I'm looking at!
